# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error, r2_score, mean_absolute_percentage_error, make_scorer
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from scipy.stats import randint, uniform

from sklearn.model_selection import RandomizedSearchCV

from sklearn.model_selection import KFold
pd.set_option('display.max_rows', None)

# %% [markdown]
# # 1. Data Analyze

# %%
df=pd.read_csv('/content/complete_cleaned_data (1).csv')
print(df.shape)
df.head()
# Out:
# (47848, 309)
#    ClosePrice  ViewYN  PoolPrivateYN   Latitude   Longitude  LivingArea  \
# 0    890000.0       1              0  34.180411 -118.342020      1434.0
# 1   1138000.0       0              0  32.574359 -117.023836      2872.0
# 2    681877.0       1              0  33.725080 -117.222302      2824.0
# 3    900000.0       1              0  34.203479 -118.643567      2500.0
# 4    862000.0       0              0  34.460368 -118.490755      2363.0
#
#    AttachedGarageYN  ParkingTotal  BathroomsTotalInteger  BedroomsTotal  ...  \
# 0                 0             1                    1.0            3.0  ...
# 1                 1             6                    3.0            5.0  ...
# 2                 1             2                    3.0            5.0  ...
# 3                 1             2                    3.0            5.0  ...
# 4                 1             2                    3.0            5.0  ...
#
#    District__West Covina Unified School District  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    District__Western Placer Unified School District  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
#
#    District__Willits Unified School District  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    District__Willows Unified School District  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    District__Windsor Unified School District  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    District__Wiseburn Unified School District  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
#
#    District__Woodland Joint Unified School District  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
#
#    District__Yosemite Unified School District  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
#
#    District__Yuba City Unified School District  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
#
#    District__Yucaipa-Calimesa Joint Unified School District
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
# [5 rows x 309 columns]

# %% [markdown]
# Let's identify what data features we have.

# %%
df.dtypes
# Out:
# ClosePrice                                                  float64
# ViewYN                                                        int64
# PoolPrivateYN                                                 int64
# Latitude                                                    float64
# Longitude                                                   float64
# LivingArea                                                  float64
# AttachedGarageYN                                              int64
# ParkingTotal                                                  int64
# BathroomsTotalInteger                                       float64
# BedroomsTotal                                               float64
# FireplaceYN                                                   int64
# Stories                                                     float64
# NewConstructionYN                                             int64
# GarageSpaces                                                float64
# LotSizeSquareFeet                                           float64
# SalesTaxRate                                                float64
# UnemploymentRate                                            float64
# MortgageRate30Fixed                                         float64
# FedInterestRate                                             float64
# CPI                                                         float64
# Age                                                         float64
# LotDensity                                                  float64
# Flooring_Bamboo                                               int64
# Flooring_Brick                                                int64
# Flooring_Carpet                                               int64
# Flooring_Concrete                                             int64
# Flooring_Laminate                                             int64
# Flooring_SeeRemarks                                           int64
# Flooring_Stone                                                int64
# Flooring_Tile                                                 int64
# Flooring_Unknown                                              int64
# Flooring_Vinyl                                                int64
# Flooring_Wood                                                 int64
# District__ABC Unified School District                          bool
# District__Acton-Agua Dulce Unified School District             bool
# District__Alameda City Unified School District                 bool
# District__Albany City Unified School District                  bool
# District__Alhambra Unified School District                     bool
# District__Alvord Unified School District                       bool
# District__Amador County Unified School District                bool
# District__Antioch Unified School District                      bool
# District__Apple Valley Unified School District                 bool
# District__Arcadia Unified School District                      bool
# District__Atascadero Unified School District                   bool
# District__Azusa Unified School District                        bool
# District__Baldwin Park Unified School District                 bool
# District__Banning Unified School District                      bool
# District__Barstow Unified School District                      bool
# District__Bassett Unified School District                      bool
# District__Bear Valley Unified School District                  bool
# District__Beaumont Unified School District                     bool
# District__Bellflower Unified School District                   bool
# District__Benicia Unified School District                      bool
# District__Berkeley Unified School District                     bool
# District__Beverly Hills Unified School District                bool
# District__Big Oak Flat-Groveland Unified School District       bool
# District__Biggs Unified School District                        bool
# District__Bonita Unified School District                       bool
# District__Bonsall Unified School District                      bool
# District__Borrego Springs Unified School District              bool
# District__Brea-Olinda Unified School District                  bool
# District__Burbank Unified School District                      bool
# District__Cabrillo Unified School District                     bool
# District__Calaveras Unified School District                    bool
# District__Capistrano Unified School District                   bool
# District__Carlsbad Unified School District                     bool
# District__Carpinteria Unified School District                  bool
# District__Caruthers Unified School District                    bool
# District__Castro Valley Unified School District                bool
# District__Center Joint Unified School District                 bool
# District__Central Unified School District                      bool
# District__Ceres Unified School District                        bool
# District__Charter Oak Unified School District                  bool
# District__Chawanakee Unified School District                   bool
# District__Chico Unified School District                        bool
# District__Chino Valley Unified School District                 bool
# District__Claremont Unified School District                    bool
# District__Cloverdale Unified School District                   bool
# District__Clovis Unified School District                       bool
# District__Coachella Valley Unified School District             bool
# District__Coalinga-Huron Unified School District               bool
# District__Coast Unified School District                        bool
# District__Colton Joint Unified School District                 bool
# District__Colusa Unified School District                       bool
# District__Compton Unified School District                      bool
# District__Conejo Valley Unified School District                bool
# District__Corona-Norco Unified School District                 bool
# District__Coronado Unified School District                     bool
# District__Covina-Valley Unified School District                bool
# District__Culver City Unified School District                  bool
# District__Cutler-Orosi Joint Unified School District           bool
# District__Cuyama Joint Unified School District                 bool
# District__Davis Joint Unified School District                  bool
# District__Delhi Unified School District                        bool
# District__Denair Unified School District                       bool
# District__Desert Sands Unified School District                 bool
# District__Dinuba Unified School District                       bool
# District__Dixon Unified School District                        bool
# District__Downey Unified School District                       bool
# District__Duarte Unified School District                       bool
# District__Dublin Unified School District                       bool
# District__Durham Unified School District                       bool
# District__El Rancho Unified School District                    bool
# District__El Segundo Unified School District                   bool
# District__El Tejon Unified School District                     bool
# District__Elk Grove Unified School District                    bool
# District__Emery Unified School District                        bool
# District__Escalon Unified School District                      bool
# District__Fairfield-Suisun Unified School District             bool
# District__Fillmore Unified School District                     bool
# District__Firebaugh-Las Deltas Unified School District         bool
# District__Folsom-Cordova Unified School District               bool
# District__Fontana Unified School District                      bool
# District__Fort Bragg Unified School District                   bool
# District__Fowler Unified School District                       bool
# District__Fremont Unified School District                      bool
# District__Fresno Unified School District                       bool
# District__Garden Grove Unified School District                 bool
# District__Gateway Unified School District                      bool
# District__Gilroy Unified School District                       bool
# District__Glendale Unified School District                     bool
# District__Glendora Unified School District                     bool
# District__Golden Valley Unified School District                bool
# District__Gridley Unified School District                      bool
# District__Gustine Unified School District                      bool
# District__Hacienda La Puente Unified School District           bool
# District__Hamilton Unified School District                     bool
# District__Hayward Unified School District                      bool
# District__Hemet Unified School District                        bool
# District__Hesperia Unified School District                     bool
# District__Hilmar Unified School District                       bool
# District__Holtville Unified School District                    bool
# District__Hughson Unified School District                      bool
# District__Imperial Unified School District                     bool
# District__Inglewood Unified School District                    bool
# District__Irvine Unified School District                       bool
# District__John Swett Unified School District                   bool
# District__Jurupa Unified School District                       bool
# District__Kelseyville Unified School District                  bool
# District__Kings Canyon Joint Unified School District           bool
# District__Konocti Unified School District                      bool
# District__La Cañada Unified School District                    bool
# District__Laguna Beach Unified School District                 bool
# District__Lake Elsinore Unified School District                bool
# District__Lake Tahoe Unified School District                   bool
# District__Lakeport Unified School District                     bool
# District__Lammersville Joint Unified School District           bool
# District__Las Virgenes Unified School District                 bool
# District__Lincoln Unified School District                      bool
# District__Live Oak Unified School District                     bool
# District__Livermore Valley Joint Unified School District       bool
# District__Lodi Unified School District                         bool
# District__Lompoc Unified School District                       bool
# District__Long Beach Unified School District                   bool
# District__Los Alamitos Unified School District                 bool
# District__Los Angeles Unified School District                  bool
# District__Los Banos Unified School District                    bool
# District__Los Molinos Unified School District                  bool
# District__Lucerne Valley Unified School District               bool
# District__Lucia Mar Unified School District                    bool
# District__Lynwood Unified School District                      bool
# District__Madera Unified School District                       bool
# District__Mammoth Unified School District                      bool
# District__Manhattan Beach Unified School District              bool
# District__Manteca Unified School District                      bool
# District__Maricopa Unified School District                     bool
# District__Mariposa County Unified School District              bool
# District__Martinez Unified School District                     bool
# District__Marysville Joint Unified School District             bool
# District__Mendocino Unified School District                    bool
# District__Middletown Unified School District                   bool
# District__Milpitas Unified School District                     bool
# District__Mojave Unified School District                       bool
# District__Monrovia Unified School District                     bool
# District__Montebello Unified School District                   bool
# District__Monterey Peninsula Unified School District           bool
# District__Moorpark Unified School District                     bool
# District__Moreno Valley Unified School District                bool
# District__Morgan Hill Unified School District                  bool
# District__Morongo Unified School District                      bool
# District__Mount Diablo Unified School District                 bool
# District__Mountain Empire Unified School District              bool
# District__Muroc Joint Unified School District                  bool
# District__Murrieta Valley Unified School District              bool
# District__Napa Valley Unified School District                  bool
# District__Natomas Unified School District                      bool
# District__Needles Unified School District                      bool
# District__New Haven Unified School District                    bool
# District__Newark Unified School District                       bool
# District__Newman-Crows Landing Unified School District         bool
# District__Newport-Mesa Unified School District                 bool
# District__North Monterey County Unified School District        bool
# District__Norwalk-La Mirada Unified School District            bool
# District__Novato Unified School District                       bool
# District__Oak Park Unified School District                     bool
# District__Oakdale Joint Unified School District                bool
# District__Oakland Unified School District                      bool
# District__Oceanside Unified School District                    bool
# District__Ojai Unified School District                         bool
# District__Orange Unified School District                       bool
# District__Orland Joint Unified School District                 bool
# District__Pacific Grove Unified School District                bool
# District__Pajaro Valley Joint Unified School District          bool
# District__Palm Springs Unified School District                 bool
# District__Palo Alto Unified School District                    bool
# District__Palo Verde Unified School District                   bool
# District__Palos Verdes Peninsula Unified School District       bool
# District__Paradise Unified School District                     bool
# District__Paramount Unified School District                    bool
# District__Pasadena Unified School District                     bool
# District__Paso Robles Joint Unified School District            bool
# District__Patterson Joint Unified School District              bool
# District__Piedmont City Unified School District                bool
# District__Pittsburg Unified School District                    bool
# District__Placentia-Yorba Linda Unified School District        bool
# District__Pleasanton Unified School District                   bool
# District__Plumas Unified School District                       bool
# District__Pomona Unified School District                       bool
# District__Porterville Unified School District                  bool
# District__Poway Unified School District                        bool
# District__Princeton Joint Unified School District              bool
# District__Ramona City Unified School District                  bool
# District__Redlands Unified School District                     bool
# District__Redondo Beach Unified School District                bool
# District__Reef-Sunset Unified School District                  bool
# District__Rialto Unified School District                       bool
# District__Rim of the World Unified School District             bool
# District__Ripon Unified School District                        bool
# District__River Delta Joint Unified School District            bool
# District__Riverbank Unified School District                    bool
# District__Riverdale Joint Unified School District              bool
# District__Riverside Unified School District                    bool
# District__Rocklin Unified School District                      bool
# District__Rowland Unified School District                      bool
# District__Sacramento City Unified School District              bool
# District__Saddleback Valley Unified School District            bool
# District__San Bernardino City Unified School District          bool
# District__San Diego City Unified School District               bool
# District__San Francisco Unified School District                bool
# District__San Gabriel Unified School District                  bool
# District__San Jacinto Unified School District                  bool
# District__San Jose Unified School District                     bool
# District__San Juan Unified School District                     bool
# District__San Leandro Unified School District                  bool
# District__San Lorenzo Unified School District                  bool
# District__San Lorenzo Valley Unified School District           bool
# District__San Luis Coastal Unified School District             bool
# District__San Marcos Unified School District                   bool
# District__San Marino Unified School District                   bool
# District__San Ramon Valley Unified School District             bool
# District__Sanger Unified School District                       bool
# District__Santa Ana Unified School District                    bool
# District__Santa Barbara Unified School District                bool
# District__Santa Clara Unified School District                  bool
# District__Santa Monica-Malibu Unified School District          bool
# District__Santa Paula Unified School District                  bool
# District__Selma Unified School District                        bool
# District__Shandon Joint Unified School District                bool
# District__Shoreline Unified School District                    bool
# District__Sierra Sands Unified School District                 bool
# District__Sierra Unified School District                       bool
# District__Silver Valley Unified School District                bool
# District__Simi Valley Unified School District                  bool
# District__Snowline Joint Unified School District               bool
# District__Soledad Unified School District                      bool
# District__Sonoma Valley Unified School District                bool
# District__South Pasadena Unified School District               bool
# District__South San Francisco Unified School District          bool
# District__Southern Kern Unified School District                bool
# District__Stockton Unified School District                     bool
# District__Sunol Glen Unified School District                   bool
# District__Tahoe-Truckee Unified School District                bool
# District__Tehachapi Unified School District                    bool
# District__Temecula Valley Unified School District              bool
# District__Temple City Unified School District                  bool
# District__Templeton Unified School District                    bool
# District__Torrance Unified School District                     bool
# District__Tracy Unified School District                        bool
# District__Travis Unified School District                       bool
# District__Trinity Alps Unified School District                 bool
# District__Turlock Unified School District                      bool
# District__Tustin Unified School District                       bool
# District__Twin Rivers Unified School District                  bool
# District__Ukiah Unified School District                        bool
# District__Unknown                                              bool
# District__Upland Unified School District                       bool
# District__Upper Lake Unified School District                   bool
# District__Vacaville Unified School District                    bool
# District__Val Verde Unified School District                    bool
# District__Vallejo City Unified School District                 bool
# District__Valley Center-Pauma Unified School District          bool
# District__Ventura Unified School District                      bool
# District__Visalia Unified School District                      bool
# District__Vista Unified School District                        bool
# District__Walnut Valley Unified School District                bool
# District__Warner Unified School District                       bool
# District__Washington Unified School District                   bool
# District__Waterford Unified School District                    bool
# District__West Contra Costa Unified School District            bool
# District__West Covina Unified School District                  bool
# District__Western Placer Unified School District               bool
# District__Willits Unified School District                      bool
# District__Willows Unified School District                      bool
# District__Windsor Unified School District                      bool
# District__Wiseburn Unified School District                     bool
# District__Woodland Joint Unified School District               bool
# District__Yosemite Unified School District                     bool
# District__Yuba City Unified School District                    bool
# District__Yucaipa-Calimesa Joint Unified School District       bool
# dtype: object

# %% [markdown]
# We can identify there are many encoding features of **District** and **Flooring**. We will reverse those features to identify any implicit and explicit missing values.

# %%
flooring= []

for col in df.columns:
  if col.startswith("Flooring_"):
    flooring.append(col)

df["FlooringType"]=df[flooring].apply(lambda x: x.idxmax(), axis=1)
df["FlooringType"] = df["FlooringType"].str.replace("Flooring_", "")

df=df.drop(columns=flooring)

# %%
District = []

for col in df.columns:
  if col.startswith("District_"):
    District.append(col)

df["SchoolDistrict"]=df[District].apply(lambda x: x.idxmax(), axis=1)
df["SchoolDistrict"] = df["SchoolDistrict"].str.replace("Flooring_", "")

df=df.drop(columns=District)

# %%
df.dtypes
# Out:
# ClosePrice               float64
# ViewYN                     int64
# PoolPrivateYN              int64
# Latitude                 float64
# Longitude                float64
# LivingArea               float64
# AttachedGarageYN           int64
# ParkingTotal               int64
# BathroomsTotalInteger    float64
# BedroomsTotal            float64
# FireplaceYN                int64
# Stories                  float64
# NewConstructionYN          int64
# GarageSpaces             float64
# LotSizeSquareFeet        float64
# SalesTaxRate             float64
# UnemploymentRate         float64
# MortgageRate30Fixed      float64
# FedInterestRate          float64
# CPI                      float64
# Age                      float64
# LotDensity               float64
# FlooringType              object
# SchoolDistrict            object
# dtype: object

# %% [markdown]
# # 2. Data Cleaning
#
# We will identify any missing values in this dataset.

# %%
df.isna().sum()
# Out:
# ClosePrice                0
# ViewYN                    0
# PoolPrivateYN             0
# Latitude                  0
# Longitude                 0
# LivingArea                0
# AttachedGarageYN          0
# ParkingTotal              0
# BathroomsTotalInteger     0
# BedroomsTotal             0
# FireplaceYN               0
# Stories                   0
# NewConstructionYN         0
# GarageSpaces              0
# LotSizeSquareFeet         0
# SalesTaxRate              0
# UnemploymentRate          0
# MortgageRate30Fixed       0
# FedInterestRate           0
# CPI                       0
# Age                      11
# LotDensity                0
# FlooringType              0
# SchoolDistrict            0
# dtype: int64

# %% [markdown]
# Due to data cleaning part of **Age** from Tara, we will drop that 11 explicit missing values.

# %%
df.dropna(subset=["Age"], inplace=True)
df.isna().sum()
# Out:
# ClosePrice               0
# ViewYN                   0
# PoolPrivateYN            0
# Latitude                 0
# Longitude                0
# LivingArea               0
# AttachedGarageYN         0
# ParkingTotal             0
# BathroomsTotalInteger    0
# BedroomsTotal            0
# FireplaceYN              0
# Stories                  0
# NewConstructionYN        0
# GarageSpaces             0
# LotSizeSquareFeet        0
# SalesTaxRate             0
# UnemploymentRate         0
# MortgageRate30Fixed      0
# FedInterestRate          0
# CPI                      0
# Age                      0
# LotDensity               0
# FlooringType             0
# SchoolDistrict           0
# dtype: int64

# %% [markdown]
# There are no explicit missing values, now we will check if there is implicit missing values. All the numerical features are not object that there is no implicit missing values. Let's check the categorical features.

# %%
df["SchoolDistrict"].value_counts()
# Out:
# SchoolDistrict
# District__Unknown                                           11385
# District__Los Angeles Unified School District                4097
# District__San Diego City Unified School District             1226
# District__Capistrano Unified School District                  994
# District__Desert Sands Unified School District                963
# District__Corona-Norco Unified School District                795
# District__Palm Springs Unified School District                729
# District__Riverside Unified School District                   713
# District__Hemet Unified School District                       673
# District__Long Beach Unified School District                  628
# District__Oakland Unified School District                     616
# District__Temecula Valley Unified School District             614
# District__Mount Diablo Unified School District                560
# District__San Bernardino City Unified School District         543
# District__Lake Elsinore Unified School District               534
# District__Saddleback Valley Unified School District           478
# District__Moreno Valley Unified School District               461
# District__Orange Unified School District                      444
# District__Hesperia Unified School District                    442
# District__Apple Valley Unified School District                425
# District__Beaumont Unified School District                    411
# District__Chino Valley Unified School District                406
# District__Murrieta Valley Unified School District             403
# District__Redlands Unified School District                    388
# District__West Contra Costa Unified School District           371
# District__Vista Unified School District                       359
# District__San Ramon Valley Unified School District            355
# District__Conejo Valley Unified School District               350
# District__Simi Valley Unified School District                 349
# District__Poway Unified School District                       347
# District__Newport-Mesa Unified School District                340
# District__Morongo Unified School District                     332
# District__Fontana Unified School District                     327
# District__Placentia-Yorba Linda Unified School District       324
# District__Chico Unified School District                       321
# District__Antioch Unified School District                     297
# District__Pasadena Unified School District                    296
# District__Garden Grove Unified School District                287
# District__Coachella Valley Unified School District            284
# District__Irvine Unified School District                      282
# District__Livermore Valley Joint Unified School District      260
# District__Bear Valley Unified School District                 258
# District__Torrance Unified School District                    243
# District__Rialto Unified School District                      239
# District__Pomona Unified School District                      235
# District__Ventura Unified School District                     235
# District__Rim of the World Unified School District            235
# District__Lucia Mar Unified School District                   233
# District__San Marcos Unified School District                  232
# District__Oceanside Unified School District                   229
# District__Fremont Unified School District                     224
# District__San Luis Coastal Unified School District            222
# District__Norwalk-La Mirada Unified School District           221
# District__Jurupa Unified School District                      214
# District__Glendale Unified School District                    207
# District__Tustin Unified School District                      206
# District__Yucaipa-Calimesa Joint Unified School District      204
# District__Snowline Joint Unified School District              194
# District__Val Verde Unified School District                   188
# District__Hacienda La Puente Unified School District          185
# District__San Jacinto Unified School District                 183
# District__Upland Unified School District                      181
# District__Compton Unified School District                     178
# District__Alvord Unified School District                      177
# District__Palos Verdes Peninsula Unified School District      177
# District__Carlsbad Unified School District                    173
# District__Hayward Unified School District                     169
# District__Las Virgenes Unified School District                168
# District__Banning Unified School District                     164
# District__Pleasanton Unified School District                  163
# District__Colton Joint Unified School District                160
# District__Burbank Unified School District                     158
# District__Rowland Unified School District                     153
# District__Downey Unified School District                      148
# District__Berkeley Unified School District                    145
# District__Paso Robles Joint Unified School District           141
# District__ABC Unified School District                         138
# District__Santa Ana Unified School District                   136
# District__Covina-Valley Unified School District               128
# District__Bonita Unified School District                      127
# District__Paradise Unified School District                    124
# District__Walnut Valley Unified School District               124
# District__Bellflower Unified School District                  123
# District__Claremont Unified School District                   114
# District__Ramona City Unified School District                 107
# District__Brea-Olinda Unified School District                 107
# District__Glendora Unified School District                    106
# District__San Lorenzo Unified School District                 104
# District__Pittsburg Unified School District                   102
# District__Alhambra Unified School District                    102
# District__Vallejo City Unified School District                101
# District__Valley Center-Pauma Unified School District         100
# District__West Covina Unified School District                  98
# District__Azusa Unified School District                        96
# District__Montebello Unified School District                   95
# District__Dublin Unified School District                       94
# District__Los Alamitos Unified School District                 91
# District__Redondo Beach Unified School District                90
# District__Alameda City Unified School District                 90
# District__Atascadero Unified School District                   89
# District__Arcadia Unified School District                      89
# District__Manhattan Beach Unified School District              85
# District__Castro Valley Unified School District                84
# District__Clovis Unified School District                       81
# District__San Leandro Unified School District                  80
# District__Southern Kern Unified School District                78
# District__Fresno Unified School District                       77
# District__Moorpark Unified School District                     77
# District__Martinez Unified School District                     77
# District__New Haven Unified School District                    76
# District__Manteca Unified School District                      75
# District__Barstow Unified School District                      74
# District__Monrovia Unified School District                     74
# District__Bonsall Unified School District                      74
# District__Charter Oak Unified School District                  71
# District__Laguna Beach Unified School District                 70
# District__El Rancho Unified School District                    69
# District__El Tejon Unified School District                     68
# District__Inglewood Unified School District                    66
# District__Newark Unified School District                       61
# District__Baldwin Park Unified School District                 60
# District__Ojai Unified School District                         59
# District__Fairfield-Suisun Unified School District             56
# District__Middletown Unified School District                   55
# District__Duarte Unified School District                       51
# District__San Gabriel Unified School District                  51
# District__Kelseyville Unified School District                  47
# District__Madera Unified School District                       47
# District__Konocti Unified School District                      47
# District__Santa Monica-Malibu Unified School District          47
# District__La Cañada Unified School District                    47
# District__Mojave Unified School District                       45
# District__Santa Paula Unified School District                  45
# District__South Pasadena Unified School District               44
# District__Paramount Unified School District                    42
# District__Fillmore Unified School District                     42
# District__Tehachapi Unified School District                    41
# District__Stockton Unified School District                     40
# District__Oak Park Unified School District                     40
# District__Tracy Unified School District                        40
# District__Elk Grove Unified School District                    38
# District__Temple City Unified School District                  37
# District__San Marino Unified School District                   37
# District__Coast Unified School District                        36
# District__Bassett Unified School District                      35
# District__Mountain Empire Unified School District              35
# District__Lompoc Unified School District                       35
# District__Culver City Unified School District                  33
# District__Los Banos Unified School District                    33
# District__Vacaville Unified School District                    33
# District__Yosemite Unified School District                     31
# District__Coronado Unified School District                     31
# District__Sacramento City Unified School District              31
# District__Lakeport Unified School District                     31
# District__Fort Bragg Unified School District                   30
# District__El Segundo Unified School District                   30
# District__Visalia Unified School District                      29
# District__Orland Joint Unified School District                 29
# District__Lucerne Valley Unified School District               28
# District__Lammersville Joint Unified School District           28
# District__San Juan Unified School District                     27
# District__Piedmont City Unified School District                27
# District__John Swett Unified School District                   26
# District__Central Unified School District                      25
# District__Lynwood Unified School District                      25
# District__Borrego Springs Unified School District              25
# District__Lodi Unified School District                         24
# District__San Francisco Unified School District                24
# District__Acton-Agua Dulce Unified School District             24
# District__Willows Unified School District                      24
# District__San Jose Unified School District                     24
# District__Wiseburn Unified School District                     23
# District__Twin Rivers Unified School District                  23
# District__Travis Unified School District                       22
# District__Turlock Unified School District                      22
# District__Mariposa County Unified School District              21
# District__Albany City Unified School District                  21
# District__River Delta Joint Unified School District            20
# District__Templeton Unified School District                    18
# District__Marysville Joint Unified School District             16
# District__Santa Barbara Unified School District                15
# District__Patterson Joint Unified School District              15
# District__Palo Verde Unified School District                   15
# District__Chawanakee Unified School District                   14
# District__Yuba City Unified School District                    14
# District__Golden Valley Unified School District                13
# District__Santa Clara Unified School District                  12
# District__Morgan Hill Unified School District                  12
# District__Napa Valley Unified School District                  11
# District__Coalinga-Huron Unified School District               11
# District__Milpitas Unified School District                     11
# District__Gridley Unified School District                      11
# District__Sierra Sands Unified School District                 10
# District__Mendocino Unified School District                     9
# District__South San Francisco Unified School District           9
# District__Benicia Unified School District                       9
# District__Natomas Unified School District                       9
# District__Beverly Hills Unified School District                 8
# District__Kings Canyon Joint Unified School District            8
# District__Durham Unified School District                        7
# District__Gilroy Unified School District                        7
# District__Sanger Unified School District                        7
# District__Newman-Crows Landing Unified School District          7
# District__Los Molinos Unified School District                   6
# District__Shandon Joint Unified School District                 6
# District__Delhi Unified School District                         6
# District__Western Placer Unified School District                6
# District__Folsom-Cordova Unified School District                6
# District__Lincoln Unified School District                       6
# District__Carpinteria Unified School District                   6
# District__Imperial Unified School District                      6
# District__Gustine Unified School District                       5
# District__Novato Unified School District                        5
# District__Center Joint Unified School District                  4
# District__Oakdale Joint Unified School District                 4
# District__Trinity Alps Unified School District                  4
# District__Hilmar Unified School District                        4
# District__Fowler Unified School District                        4
# District__Washington Unified School District                    4
# District__Monterey Peninsula Unified School District            4
# District__Plumas Unified School District                        4
# District__Sierra Unified School District                        3
# District__Selma Unified School District                         3
# District__Windsor Unified School District                       3
# District__Rocklin Unified School District                       3
# District__Colusa Unified School District                        3
# District__Biggs Unified School District                         3
# District__Hughson Unified School District                       3
# District__Pajaro Valley Joint Unified School District           3
# District__Warner Unified School District                        3
# District__Amador County Unified School District                 3
# District__Willits Unified School District                       3
# District__Maricopa Unified School District                      3
# District__Lake Tahoe Unified School District                    3
# District__Escalon Unified School District                       3
# District__Silver Valley Unified School District                 3
# District__Ukiah Unified School District                         3
# District__Upper Lake Unified School District                    3
# District__Calaveras Unified School District                     3
# District__Needles Unified School District                       2
# District__San Lorenzo Valley Unified School District            2
# District__Riverbank Unified School District                     2
# District__Ceres Unified School District                         2
# District__Emery Unified School District                         2
# District__Palo Alto Unified School District                     2
# District__Sonoma Valley Unified School District                 2
# District__Live Oak Unified School District                      2
# District__Cabrillo Unified School District                      2
# District__Ripon Unified School District                         2
# District__Big Oak Flat-Groveland Unified School District        2
# District__Caruthers Unified School District                     2
# District__Reef-Sunset Unified School District                   1
# District__Dinuba Unified School District                        1
# District__Holtville Unified School District                     1
# District__Denair Unified School District                        1
# District__Gateway Unified School District                       1
# District__Waterford Unified School District                     1
# District__Porterville Unified School District                   1
# District__Cutler-Orosi Joint Unified School District            1
# District__Hamilton Unified School District                      1
# District__Cuyama Joint Unified School District                  1
# District__Soledad Unified School District                       1
# District__Pacific Grove Unified School District                 1
# District__Sunol Glen Unified School District                    1
# District__Woodland Joint Unified School District                1
# District__Tahoe-Truckee Unified School District                 1
# District__Princeton Joint Unified School District               1
# District__Muroc Joint Unified School District                   1
# District__Dixon Unified School District                         1
# District__Cloverdale Unified School District                    1
# District__Mammoth Unified School District                       1
# District__Shoreline Unified School District                     1
# District__North Monterey County Unified School District         1
# District__Davis Joint Unified School District                   1
# District__Firebaugh-Las Deltas Unified School District          1
# District__Riverdale Joint Unified School District               1
# Name: count, dtype: int64

# %%
#Take off "District_"
df["SchoolDistrict"] = df["SchoolDistrict"].str.replace("District__", '')

count_district=df["SchoolDistrict"].value_counts()
count_district
# Out:
# SchoolDistrict
# Unknown                                           11385
# Los Angeles Unified School District                4097
# San Diego City Unified School District             1226
# Capistrano Unified School District                  994
# Desert Sands Unified School District                963
# Corona-Norco Unified School District                795
# Palm Springs Unified School District                729
# Riverside Unified School District                   713
# Hemet Unified School District                       673
# Long Beach Unified School District                  628
# Oakland Unified School District                     616
# Temecula Valley Unified School District             614
# Mount Diablo Unified School District                560
# San Bernardino City Unified School District         543
# Lake Elsinore Unified School District               534
# Saddleback Valley Unified School District           478
# Moreno Valley Unified School District               461
# Orange Unified School District                      444
# Hesperia Unified School District                    442
# Apple Valley Unified School District                425
# Beaumont Unified School District                    411
# Chino Valley Unified School District                406
# Murrieta Valley Unified School District             403
# Redlands Unified School District                    388
# West Contra Costa Unified School District           371
# Vista Unified School District                       359
# San Ramon Valley Unified School District            355
# Conejo Valley Unified School District               350
# Simi Valley Unified School District                 349
# Poway Unified School District                       347
# Newport-Mesa Unified School District                340
# Morongo Unified School District                     332
# Fontana Unified School District                     327
# Placentia-Yorba Linda Unified School District       324
# Chico Unified School District                       321
# Antioch Unified School District                     297
# Pasadena Unified School District                    296
# Garden Grove Unified School District                287
# Coachella Valley Unified School District            284
# Irvine Unified School District                      282
# Livermore Valley Joint Unified School District      260
# Bear Valley Unified School District                 258
# Torrance Unified School District                    243
# Rialto Unified School District                      239
# Pomona Unified School District                      235
# Ventura Unified School District                     235
# Rim of the World Unified School District            235
# Lucia Mar Unified School District                   233
# San Marcos Unified School District                  232
# Oceanside Unified School District                   229
# Fremont Unified School District                     224
# San Luis Coastal Unified School District            222
# Norwalk-La Mirada Unified School District           221
# Jurupa Unified School District                      214
# Glendale Unified School District                    207
# Tustin Unified School District                      206
# Yucaipa-Calimesa Joint Unified School District      204
# Snowline Joint Unified School District              194
# Val Verde Unified School District                   188
# Hacienda La Puente Unified School District          185
# San Jacinto Unified School District                 183
# Upland Unified School District                      181
# Compton Unified School District                     178
# Alvord Unified School District                      177
# Palos Verdes Peninsula Unified School District      177
# Carlsbad Unified School District                    173
# Hayward Unified School District                     169
# Las Virgenes Unified School District                168
# Banning Unified School District                     164
# Pleasanton Unified School District                  163
# Colton Joint Unified School District                160
# Burbank Unified School District                     158
# Rowland Unified School District                     153
# Downey Unified School District                      148
# Berkeley Unified School District                    145
# Paso Robles Joint Unified School District           141
# ABC Unified School District                         138
# Santa Ana Unified School District                   136
# Covina-Valley Unified School District               128
# Bonita Unified School District                      127
# Paradise Unified School District                    124
# Walnut Valley Unified School District               124
# Bellflower Unified School District                  123
# Claremont Unified School District                   114
# Ramona City Unified School District                 107
# Brea-Olinda Unified School District                 107
# Glendora Unified School District                    106
# San Lorenzo Unified School District                 104
# Pittsburg Unified School District                   102
# Alhambra Unified School District                    102
# Vallejo City Unified School District                101
# Valley Center-Pauma Unified School District         100
# West Covina Unified School District                  98
# Azusa Unified School District                        96
# Montebello Unified School District                   95
# Dublin Unified School District                       94
# Los Alamitos Unified School District                 91
# Redondo Beach Unified School District                90
# Alameda City Unified School District                 90
# Atascadero Unified School District                   89
# Arcadia Unified School District                      89
# Manhattan Beach Unified School District              85
# Castro Valley Unified School District                84
# Clovis Unified School District                       81
# San Leandro Unified School District                  80
# Southern Kern Unified School District                78
# Fresno Unified School District                       77
# Moorpark Unified School District                     77
# Martinez Unified School District                     77
# New Haven Unified School District                    76
# Manteca Unified School District                      75
# Barstow Unified School District                      74
# Monrovia Unified School District                     74
# Bonsall Unified School District                      74
# Charter Oak Unified School District                  71
# Laguna Beach Unified School District                 70
# El Rancho Unified School District                    69
# El Tejon Unified School District                     68
# Inglewood Unified School District                    66
# Newark Unified School District                       61
# Baldwin Park Unified School District                 60
# Ojai Unified School District                         59
# Fairfield-Suisun Unified School District             56
# Middletown Unified School District                   55
# Duarte Unified School District                       51
# San Gabriel Unified School District                  51
# Kelseyville Unified School District                  47
# Madera Unified School District                       47
# Konocti Unified School District                      47
# Santa Monica-Malibu Unified School District          47
# La Cañada Unified School District                    47
# Mojave Unified School District                       45
# Santa Paula Unified School District                  45
# South Pasadena Unified School District               44
# Paramount Unified School District                    42
# Fillmore Unified School District                     42
# Tehachapi Unified School District                    41
# Stockton Unified School District                     40
# Oak Park Unified School District                     40
# Tracy Unified School District                        40
# Elk Grove Unified School District                    38
# Temple City Unified School District                  37
# San Marino Unified School District                   37
# Coast Unified School District                        36
# Bassett Unified School District                      35
# Mountain Empire Unified School District              35
# Lompoc Unified School District                       35
# Culver City Unified School District                  33
# Los Banos Unified School District                    33
# Vacaville Unified School District                    33
# Yosemite Unified School District                     31
# Coronado Unified School District                     31
# Sacramento City Unified School District              31
# Lakeport Unified School District                     31
# Fort Bragg Unified School District                   30
# El Segundo Unified School District                   30
# Visalia Unified School District                      29
# Orland Joint Unified School District                 29
# Lucerne Valley Unified School District               28
# Lammersville Joint Unified School District           28
# San Juan Unified School District                     27
# Piedmont City Unified School District                27
# John Swett Unified School District                   26
# Central Unified School District                      25
# Lynwood Unified School District                      25
# Borrego Springs Unified School District              25
# Lodi Unified School District                         24
# San Francisco Unified School District                24
# Acton-Agua Dulce Unified School District             24
# Willows Unified School District                      24
# San Jose Unified School District                     24
# Wiseburn Unified School District                     23
# Twin Rivers Unified School District                  23
# Travis Unified School District                       22
# Turlock Unified School District                      22
# Mariposa County Unified School District              21
# Albany City Unified School District                  21
# River Delta Joint Unified School District            20
# Templeton Unified School District                    18
# Marysville Joint Unified School District             16
# Santa Barbara Unified School District                15
# Patterson Joint Unified School District              15
# Palo Verde Unified School District                   15
# Chawanakee Unified School District                   14
# Yuba City Unified School District                    14
# Golden Valley Unified School District                13
# Santa Clara Unified School District                  12
# Morgan Hill Unified School District                  12
# Napa Valley Unified School District                  11
# Coalinga-Huron Unified School District               11
# Milpitas Unified School District                     11
# Gridley Unified School District                      11
# Sierra Sands Unified School District                 10
# Mendocino Unified School District                     9
# South San Francisco Unified School District           9
# Benicia Unified School District                       9
# Natomas Unified School District                       9
# Beverly Hills Unified School District                 8
# Kings Canyon Joint Unified School District            8
# Durham Unified School District                        7
# Gilroy Unified School District                        7
# Sanger Unified School District                        7
# Newman-Crows Landing Unified School District          7
# Los Molinos Unified School District                   6
# Shandon Joint Unified School District                 6
# Delhi Unified School District                         6
# Western Placer Unified School District                6
# Folsom-Cordova Unified School District                6
# Lincoln Unified School District                       6
# Carpinteria Unified School District                   6
# Imperial Unified School District                      6
# Gustine Unified School District                       5
# Novato Unified School District                        5
# Center Joint Unified School District                  4
# Oakdale Joint Unified School District                 4
# Trinity Alps Unified School District                  4
# Hilmar Unified School District                        4
# Fowler Unified School District                        4
# Washington Unified School District                    4
# Monterey Peninsula Unified School District            4
# Plumas Unified School District                        4
# Sierra Unified School District                        3
# Selma Unified School District                         3
# Windsor Unified School District                       3
# Rocklin Unified School District                       3
# Colusa Unified School District                        3
# Biggs Unified School District                         3
# Hughson Unified School District                       3
# Pajaro Valley Joint Unified School District           3
# Warner Unified School District                        3
# Amador County Unified School District                 3
# Willits Unified School District                       3
# Maricopa Unified School District                      3
# Lake Tahoe Unified School District                    3
# Escalon Unified School District                       3
# Silver Valley Unified School District                 3
# Ukiah Unified School District                         3
# Upper Lake Unified School District                    3
# Calaveras Unified School District                     3
# Needles Unified School District                       2
# San Lorenzo Valley Unified School District            2
# Riverbank Unified School District                     2
# Ceres Unified School District                         2
# Emery Unified School District                         2
# Palo Alto Unified School District                     2
# Sonoma Valley Unified School District                 2
# Live Oak Unified School District                      2
# Cabrillo Unified School District                      2
# Ripon Unified School District                         2
# Big Oak Flat-Groveland Unified School District        2
# Caruthers Unified School District                     2
# Reef-Sunset Unified School District                   1
# Dinuba Unified School District                        1
# Holtville Unified School District                     1
# Denair Unified School District                        1
# Gateway Unified School District                       1
# Waterford Unified School District                     1
# Porterville Unified School District                   1
# Cutler-Orosi Joint Unified School District            1
# Hamilton Unified School District                      1
# Cuyama Joint Unified School District                  1
# Soledad Unified School District                       1
# Pacific Grove Unified School District                 1
# Sunol Glen Unified School District                    1
# Woodland Joint Unified School District                1
# Tahoe-Truckee Unified School District                 1
# Princeton Joint Unified School District               1
# Muroc Joint Unified School District                   1
# Dixon Unified School District                         1
# Cloverdale Unified School District                    1
# Mammoth Unified School District                       1
# Shoreline Unified School District                     1
# North Monterey County Unified School District         1
# Davis Joint Unified School District                   1
# Firebaugh-Las Deltas Unified School District          1
# Riverdale Joint Unified School District               1
# Name: count, dtype: int64

# %% [markdown]
# There are too many unique value in school district that would potentionally lead overfitting and noise for machine learning performance. We will group it into **Top Tier District**, **Mid Tier District**, **Low Tier District**, and **Rare District** without including Unknown.

# %%
#call all unique values without "Unknown"
count_district = df[df["SchoolDistrict"] != "Unknown"]["SchoolDistrict"].value_counts()
count_district

#Threshold for grouping the unique values
top = count_district.quantile(0.9)
mid= count_district.quantile(0.7)
low= count_district.quantile(0.5)

#Call out the grouping names including threshold into 4 different groups
def categorize_district(district):
  if district == "Unknown":
    return "Unknown"

  count = count_district[district]
  if count >= top:
    return "Top Tier District"
  elif count >= mid:
    return "Mid Tier District"
  elif count >= low:
    return "Low Tier District"
  else:
    return "Rare District"

#Apply the function
df["SchoolDistrict"] = df["SchoolDistrict"].apply(categorize_district)

#Check
df["SchoolDistrict"].value_counts(normalize=True)
# Out:
# SchoolDistrict
# Top Tier District    0.404018
# Low Tier District    0.241508
# Unknown              0.237996
# Rare District        0.116479
# Name: proportion, dtype: float64

# %% [markdown]
# Let's identify the **Flooring Type** features.

# %%
df["FlooringType"].value_counts(normalize=True)
# Out:
# FlooringType
# Unknown       0.368522
# Carpet        0.302088
# Laminate      0.105609
# Tile          0.092000
# Wood          0.052783
# Vinyl         0.043126
# SeeRemarks    0.016243
# Stone         0.009031
# Concrete      0.005832
# Bamboo        0.003867
# Brick         0.000899
# Name: proportion, dtype: float64

# %% [markdown]
# There are implicit missing values in **Flooring Type** as well. We will use Random Forest Classifier to predict the implicit missing values of **Flooring Type** and **School District**.

# %% [markdown]
# # 3. Random Forest Classifier

# %%
#Call out the copy for test and replace it to original data
df2 = df.copy()

#Call predictors for Flooring Type
predictors=["ClosePrice", "LivingArea", "BathroomsTotalInteger", "BathroomsTotalInteger", "GarageSpaces", "Longitude", "Latitude"]

le = LabelEncoder()

#Change Unknown values into explicit missing value (Since we know there are no explicit missing values, it is okay to use it.)
df2["FlooringType"]= df2["FlooringType"].replace("Unknown", np.nan)

#Divide into no explicit missing values and missing values(Unknown).
known = df2[df2["FlooringType"].notna()]
unknown=df2[df2["FlooringType"].isna()]

#Change into numerical form
known["FlooringType"]=le.fit_transform(known["FlooringType"])


x_train,x_test,y_train,y_test=train_test_split(known[predictors], known["FlooringType"], test_size=0.2, random_state=42)

#Randomforest perform predicting Flooring Type missing values using predictors of no explicit missing values of Flooring Type.
clf=RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(x_train, y_train)

y_pred=clf.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)

#Predict the missing values of Flooring Type
predict_flooring=clf.predict(unknown[predictors])

#Reverse numerical into categorical feature.
predict_flooring_labels=le.inverse_transform(predict_flooring)

#Replace it in original data of Flooring Type of Unknown
df.loc[df["FlooringType"] == "Unknown", "FlooringType"]=predict_flooring_labels

#Check
accuracy,df["FlooringType"].value_counts()
# Out:
# /tmp/ipython-input-4115475982.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   known["FlooringType"]=le.fit_transform(known["FlooringType"])
# (0.46226415094339623,
#  FlooringType
#  Carpet        27167
#  Laminate       7554
#  Tile           5618
#  Wood           3277
#  Vinyl          2399
#  SeeRemarks      824
#  Stone           461
#  Concrete        292
#  Bamboo          198
#  Brick            47
#  Name: count, dtype: int64)

# %%
predictors=["ClosePrice", "LivingArea", "BathroomsTotalInteger", "BathroomsTotalInteger", "GarageSpaces", "Longitude", "Latitude"]

df2["SchoolDistrict"]= df2["SchoolDistrict"].replace("Unknown", np.nan)

known = df2[df2["SchoolDistrict"].notna()]
unknown=df2[df2["SchoolDistrict"].isna()]

known["SchoolDistrict"]=le.fit_transform(known["SchoolDistrict"])

x_train,x_test,y_train,y_test=train_test_split(known[predictors], known["SchoolDistrict"], test_size=0.2, random_state=42)

clf.fit(x_train, y_train)


y_pred=clf.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)

predict_sd=clf.predict(unknown[predictors])
predict_sd_labels=le.inverse_transform(predict_sd)
df.loc[df["SchoolDistrict"] == "Unknown", "SchoolDistrict"]=predict_sd_labels

accuracy,df["SchoolDistrict"].value_counts()
# Out:
# /tmp/ipython-input-4284940305.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   known["SchoolDistrict"]=le.fit_transform(known["SchoolDistrict"])
# (0.9532300096008778,
#  SchoolDistrict
#  Top Tier District    23071
#  Mid Tier District    15560
#  Low Tier District     6441
#  Rare District         2765
#  Name: count, dtype: int64)

# %%
df_dum = pd.get_dummies(df, drop_first=True)

for i in df_dum.columns:
  print(i)
# Out:
# ClosePrice
# ViewYN
# PoolPrivateYN
# Latitude
# Longitude
# LivingArea
# AttachedGarageYN
# ParkingTotal
# BathroomsTotalInteger
# BedroomsTotal
# FireplaceYN
# Stories
# NewConstructionYN
# GarageSpaces
# LotSizeSquareFeet
# SalesTaxRate
# UnemploymentRate
# MortgageRate30Fixed
# FedInterestRate
# CPI
# Age
# LotDensity
# FlooringType_Brick
# FlooringType_Carpet
# FlooringType_Concrete
# FlooringType_Laminate
# FlooringType_SeeRemarks
# FlooringType_Stone
# FlooringType_Tile
# FlooringType_Vinyl
# FlooringType_Wood
# SchoolDistrict_Mid Tier District
# SchoolDistrict_Rare District
# SchoolDistrict_Top Tier District

# %%
y=df_dum['ClosePrice']
x=df_dum.drop('ClosePrice', axis=1)

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state=50)

# %%
#Call Random Forest
rfr=RandomForestRegressor(random_state=42, n_estimators=100)
rfr.fit(x_train, y_train)

y_pred=rfr.predict(x_test)


print("Train MAE:", mean_absolute_error(y_test, y_pred))
print("Train R2 score:", r2_score(y_test, y_pred))
print("Train MAPE:" , mean_absolute_percentage_error(y_test, y_pred)*100,"%")
# Out:
# Train MAE: 133947.2324080668
# Train R2 score: 0.8653037093860331
# Train MAPE: 11.962155277833801 %

# %%
# Call for hyper parameter tunning
param={
    'n_estimators': randint(100, 300),
    'max_depth':randint(1, 20),
    'min_samples_split': randint(2, 15),
    'min_samples_leaf': randint(1, 5)
}

# %%
#Call MAPE score
mape_score = make_scorer(mean_absolute_percentage_error, greater_is_better=False)

#Call K-Fold Cross-Validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)

#Train and apply K-Fold to RandomSearch Cross-Validation with scoring MAPE
rfr_cv=RandomizedSearchCV(estimator=rfr, param_distributions=param, n_iter=15, cv=kf,scoring=mape_score, n_jobs=-1)
rfr_cv.fit(x_train, y_train)

#Call the best parameter
best_param=rfr_cv.best_params_
print("Best Parameters", best_param)
# Out:
# Best Parameters {'max_depth': 15, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 220}

# %%
#Apply the best parameter to Random Forest Regressor
final_model = RandomForestRegressor(**best_param, random_state=50)
final_model.fit(x_train, y_train)

#Call both train and test prediction to identify overfitting
y_pred_train = final_model.predict(x_train)
y_pred_test = final_model.predict(x_test)

print("Train MAE:", mean_absolute_error(y_train, y_pred_train))
print("Train R2 score:", r2_score(y_train, y_pred_train))
print("Train MAPE:" , mean_absolute_percentage_error(y_train, y_pred_train)*100,"%")
print()
print("Test MAE:", mean_absolute_error(y_test, y_pred_test))
print("Test R2 score:", r2_score(y_test, y_pred_test))
print("Test MAPE:" , mean_absolute_percentage_error(y_test, y_pred_test)*100,"%")
# Out:
# Train MAE: 97148.94909393135
# Train R2 score: 0.9395268555728947
# Train MAPE: 9.237295799452983 %
#
# Test MAE: 141114.5708826923
# Test R2 score: 0.8559702620043156
# Test MAPE: 12.776124747702239 %

# %%
#Call the feature importances value used from Random Forest Regressor with sorting it.
importances = pd.Series(rfr_cv.best_estimator_.feature_importances_, index=x_train.columns)
importances = importances.sort_values(ascending=False)

# Plot
plt.figure(figsize=(14, 8))  # Larger size to fit all labels
importances.plot(kind='bar')

plt.title('Feature Importance (All Features Sorted)', fontsize=14)
plt.xlabel("Features", fontsize=12)
plt.ylabel("Importance Score", fontsize=12)
plt.xticks(rotation=75, ha='right')  # rotate labels for readability
plt.tight_layout()
plt.show()

# Set threshold
threshold = 0.002

# Identify low-importance features
low_importance_features = importances[importances < threshold].index.tolist()

# Drop them from your training and testing sets
x_train_reduced = x_train.drop(columns=low_importance_features)
x_test_reduced = x_test.drop(columns=low_importance_features)

#Show what we dropped the features that has low importances
print("Dropped Features:", low_importance_features)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3792810819.py in <cell line: 0>()
#       1 #Call the feature importances value used from Random Forest Regressor with sorting it.
# ----> 2 importances = pd.Series(rfr_cv.best_estimator_.feature_importances_, index=x_train.columns)
#       3 importances = importances.sort_values(ascending=False)
#       4
#       5 # Plot
#
# NameError: name 'rfr_cv' is not defined

# %%
#Train again
param={
    'n_estimators': randint(100, 300),
    'max_depth':randint(1, 20),
    'min_samples_split': randint(2, 15),
    'min_samples_leaf': randint(1, 5)
}

mape_score = make_scorer(mean_absolute_percentage_error, greater_is_better=False)
kf = KFold(n_splits=5, shuffle=True, random_state=42)


rfr_cv=RandomizedSearchCV(estimator=rfr, param_distributions=param, n_iter=15, cv=kf,scoring=mape_score, n_jobs=-1)
rfr_cv.fit(x_train, y_train)

# Get feature importances
importances = pd.Series(rfr_cv.best_estimator_.feature_importances_, index=x_train.columns)

# Set threshold
threshold = 0.002

# Identify low-importance features
low_importance_features = importances[importances < threshold].index.tolist()

# Drop them from your training and testing sets
x_train_reduced = x_train.drop(columns=low_importance_features)
x_test_reduced = x_test.drop(columns=low_importance_features)

#Show what we dropped the features that has low importances
print("Dropped Features:", low_importance_features)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-218961513.py in <cell line: 0>()
#      11
#      12
# ---> 13 rfr_cv=RandomizedSearchCV(estimator=rfr, param_distributions=param, n_iter=15, cv=kf,scoring=mape_score, n_jobs=-1)
#      14 rfr_cv.fit(x_train, y_train)
#      15
#
# NameError: name 'rfr' is not defined

# %%
#Train and apply K-Fold to RandomSearch Cross-Validation with scoring MAPE
rfr_cv=RandomizedSearchCV(estimator=rfr, param_distributions=param, n_iter=15, cv=kf,scoring=mape_score, n_jobs=-1)
rfr_cv.fit(x_train_reduced, y_train)

#Call the best parameter
best_param=rfr_cv.best_params_
print("Best Parameters", best_param)

#Call Random Forest Regressor only using good importances values
final_model = RandomForestRegressor(**best_param, random_state=50)
final_model.fit(x_train_reduced, y_train)

y_pred_train = final_model.predict(x_train_reduced)
y_pred_test = final_model.predict(x_test_reduced)

print("Train MAE:", mean_absolute_error(y_train, y_pred_train))
print("Train R2 score:", r2_score(y_train, y_pred_train))
print("Train MAPE:" , mean_absolute_percentage_error(y_train, y_pred_train)*100,"%")
print()
print("Test MAE:", mean_absolute_error(y_test, y_pred_test))
print("Test R2 score:", r2_score(y_test, y_pred_test))
print("Test MAPE:" , mean_absolute_percentage_error(y_test, y_pred_test)*100,"%")
# Out:
# Train MAE: 92374.83521294624
# Train R2 score: 0.9351783509638825
# Train MAPE: 8.305160807912532 %
#
# Test MAE: 137703.34572806975
# Test R2 score: 0.8582423809991196
# Test MAPE: 12.303136232232873 %

# %%
param_dist = {
    'n_estimators': randint(50, 300),
    'learning_rate': uniform(0.05, 0.25),
    'max_depth': randint(3, 10),
    'subsample': uniform(0.7, 0.3),
    'colsample_bytree': uniform(0.7, 0.3)
}

# Call XGBoost model
xgb = XGBRegressor(random_state=42)

# Call RandomizedSearchCV
random_search = RandomizedSearchCV(estimator=xgb, param_distributions=param_dist, n_iter=30, scoring='neg_mean_absolute_percentage_error', cv=5,verbose=1, n_jobs=-1, random_state=42)

#Fit the model
random_search.fit(x_train, y_train)

#Evaluate best model
best_param = random_search.best_estimator_

best_model = XGBRegressor(**best_param.get_params())
best_model.fit(x_train, y_train)

y_pred = best_model.predict(x_test)

mape = mean_absolute_percentage_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Best Parameters:", random_search.best_params_)
print(f"Test MAPE: {mape:.4f}")
print(f"Test R² Score: {r2:.4f}")
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Best Parameters: {'colsample_bytree': np.float64(0.8869894380482674), 'learning_rate': np.float64(0.13272450621316229), 'max_depth': 9, 'n_estimators': 200, 'subsample': np.float64(0.9006523757990821)}
# Test MAPE: 0.1178
# Test R² Score: 0.8779
